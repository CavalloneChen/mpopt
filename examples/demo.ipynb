# %% [markdown]
# # Optimization with MPOpt
#
# This is a demo which will show you the whole process of building, testing and analyzing your algorithm with `mpopt`.
#
# We will show the whole process of population creation, algorithm designing, benchmarking and analyzing using `mpopt`.

# %%
import numpy as np

# %% [markdown]
# ## 1. Objective Function
#
# `mpopt` use 'Evaluator' as an abstraction of objective function.
#
# For each run of optimization, an 'Evaluator' instance should be created and passed to the optimization algorithm. It holds all the information about the task and will automatically update states when some solutions are evaluated.
#
# Compared with the 'ask-tell' interface, this framework provides much more flexibility for optimization algorithm.
#
# You can get a standard evaluator from our provided benchmarks with following codes:

# %%
from mpopt.benchmarks.benchmark import Benchmark
# get benchmark CEC20 with 10 dim
benchmark = Benchmark('CEC20', 10)
# get an evaluator for the first function in benchmark
evaluator = benchmark.generate(0)

# %% [markdown]
# You are also free to build your own objective functions and evaluators. For example:

# %%
from mpopt.tools.objective import ObjFunction, Evaluator

# an callable objective function
def my_obj(x):
    return np.sum(x**2)

# create objective function
# information about my_obj is needed
obj = ObjFunction(my_obj, dim=2, lb=-1, ub=1,)

# create evaluator
# information about the optimization is need
evaluator = Evaluator(obj, max_eval=100)

# %% [markdown]
# Now the evaluator is ready for an optimization. For example, this is how random-search be implemented in our framework.

# %%
# alias
e = evaluator
dim = e.obj.dim
lb = e.obj.lb
ub = e.obj.ub

# algorithm begin
while not e.terminate():
    rand_sample = np.random.uniform(lb, ub, (1,dim))
    e(rand_sample)
print("Solution: {}. Val: {:.3e}".format(e.best_x, e.best_y))
# Out:
# Solution: [ 0.05214204 -0.07891306]. Val: 8.946e-03

# %% [markdown]
# ## 2. Population
#
# Using the evaluator, we can directly start optimization as above. However, here we focus on optimization algorithm based on population(s).
#
# `mpopt` provide a base class `BasePop` for general population and a base class  `BaseFirework` for firework in `mpopt.population.base`.
#
# You are supposed to inherit from those class, and re-write methods you changed. New population definition should be stored in 'mpopt/population' directory.
#
# For exmaple, here we build a firework population with dynamic amplitude (which is the same as [BBFWA]):

# %%
from mpopt.population.base import BaseFirework

class DynFirework(BaseFirework):
    # re-write __init__
    def __init__(self, idv, val, amp, num_spk, **kwargs):
        super().__init__(idv, val, **kwargs)

        self.amp = amp
        self.num_spk = num_spk

        # set default dynamic ratio if not given
        if 'dr_amp' not in self.__dict__:
            self.dr_amp = 1.2
        if 'dr_red' not in self.__dict__: 
            self.dr_red = 0.9

    # re-write update for dynamic ratios
    def update(self):
        if self.val - self.new_val > 1e-5:
            # improved
            self.amp *= self.dr_amp
        else:
            self.amp *= self.dr_red
        
        # update firework
        self.idv = self.new_idv
        self.val = self.new_val

# %% [markdown]
# Since we have default setting for other parts of the firework population, a `DynFirework` instance is ready to evolve with a evaluator once it is created.

# %%
# set environment
e = Evaluator(obj, max_eval=100)
dim = e.obj.dim
lb = e.obj.lb
ub = e.obj.ub

# init pop
idv = np.random.uniform(lb, ub, (dim,))
val = e(idv[np.newaxis,:])[0]

firework = DynFirework(idv, val, ub-lb, 5, lb=lb, ub=ub)
while not e.terminate():
    firework.evolve(e)
print("Solution: {}. Val: {:.3e}".format(e.best_x, e.best_y))
# Out:
# Solution: [0.01954127 0.06263937]. Val: 4.306e-03

# %% [markdown]
# ## optimization
#
# In fact, the cell above is already a runable optimization algorithm based on a single population. However, there are still two important directions to improve it.

# %% [markdown]
# ### 1. Unified Interface
#
# For the convenience to apply or analysis our algorithm, it is better to unify their interface. We require each algorithm be abstracted as a class and provide following methods:
#
# - `__init__`: Define all the parameters and states (include populations) here for reading.
#
# - `default_params(self, benchmark=None)`: Get default parameters.
#
# - `set_params(self, params)`: Set parameters.
#
# - `init(self, e)`: Init states of the algorithm.
#
# - `optimize(self, e)`: Run optimization and return the optimal value.

# %% [markdown]
# ### 2. Collaborate Multiple Populations
#
# With `mpopt`, we hope to easily implement optimizations with multiple populations. Now the evolution method for each population can be pre-defined, we only need to consider the collaboration during each iteration.
#
# In order to maximize the flexibility of the algorithms, we leave all the states and parameters of population opened. So in each itaration, you can just let each population evolve and then do whatever you want.

# %% [markdown]
# ### Example of LoTFWA (without guided mutation)
#
# We implement a LoTFWA without guided mutation algorithm as an example:

# %%
from mpopt.algorithms.base import BaseAlg

class DemoFWA(BaseAlg):

    def __init__(self, obj):
        # populations
        self.fireworks = None
        # params
        self.fw_size = None
        self.init_amp = None
        self.num_spk = None
        # load default
        self.set_params(self.default_params(obj))
    
    def default_params(self, obj):
        params = {}
        params['fw_size'] = 4
        params['init_amp'] = obj.ub - obj.lb
        params['num_spk'] = 5
        return params

    def init(self, e):
        init_pop = np.random.uniform(e.obj.lb, e.obj.ub, (self.fw_size, e.obj.dim))
        init_fit = e(init_pop)
        self.fireworks = [DynFirework(init_pop[i,:], 
                                      init_fit[i], 
                                      self.init_amp, 
                                      self.num_spk,
                                      lb=e.obj.lb,
                                      ub=e.obj.ub,) for i in range(self.fw_size)]
    
    def optimize(self, e):
        self.init(e)
        while not e.terminate():
            # evolve
            for idx in range(self.fw_size):
                self.fireworks[idx].explode()
                self.fireworks[idx].eval(e)
                self.fireworks[idx].select()
            
            # collaborate
            restart = [False] * self.fw_size
            for idx in range(self.fw_size):
                # alias
                fw = self.fireworks[idx]
                # improved
                if fw.val - fw.new_val > 1e-5:
                    rest_iter = (e.max_eval - e.num_eval) / (self.fw_size * self.num_spk)
                    if (fw.val - fw.new_val) * rest_iter > (fw.val - e.cur_y):
                        # restart fw
                        restart[idx] = True
                        restart_pop = np.random.uniform(e.obj.lb, e.obj.ub, (1, e.obj.dim))
                        restart_fit = e(restart_pop) 
                        self.fireworks[idx] = DynFirework(restart_pop[0,:],
                                                          restart_fit[0],
                                                          self.init_amp,
                                                          self.num_spk,
                                                          lb=e.obj.lb,
                                                          ub=e.obj.ub,)
            
            # update populations
            for idx in range(self.fw_size):
                if not restart[idx]:
                    self.fireworks[idx].update()
        
        return e.best_y
    
# optimize
e = Evaluator(obj, max_eval=1000)
alg = DemoFWA(obj)
alg.optimize(e)
print("Solution: {}. Val: {:.3e}".format(e.best_x, e.best_y))
# Out:
# Solution: [-0.01144639 -0.01656987]. Val: 4.056e-04

# %% [markdown]
# ## Benchmarking
#
# We provide several standard benchmarks to test your algorithm in `mpopt.benchmarks`. As we shown before, `benchmark` instance can generate evaluators which is set according to the requirements of the benchmark.
#
# We also provide a standard testing script for benchmarking in `mpopt/../runs/benchmark_opt.py` which including evaluators generation, timing, multiprocessing, and result recording. You can run a test of LoTFWA on CEC20 by typing following code:

# %%
# !python ../runs/benchmark_opt.py -b CEC20 -d 10 -a LoTFWA -r 30 -n test
# Out:
# Prob.1   , res:1.8211e+06,	 time:14.264
# Prob.1   , res:5.3030e+05,	 time:14.253
# Prob.1   , res:5.9067e+05,	 time:14.108
# Prob.1   , res:1.2467e+06,	 time:13.944
# Prob.1   , res:9.0092e+05,	 time:14.216
# Prob.1   , res:1.3756e+06,	 time:13.974
# Prob.1   , res:6.6015e+05,	 time:14.102
# Prob.1   , res:1.2402e+06,	 time:14.010
# Prob.1   , res:4.7347e+05,	 time:14.561
# Prob.1   , res:5.8092e+05,	 time:14.108
# Prob.1   , res:9.1935e+05,	 time:13.930
# Prob.1   , res:6.4906e+05,	 time:14.160
# Prob.1   , res:9.1337e+05,	 time:14.176
# Prob.1   , res:8.1814e+05,	 time:13.907
# Prob.1   , res:9.3151e+05,	 time:13.969
# Prob.1   , res:5.0619e+05,	 time:14.399
# Prob.1   , res:4.6912e+05,	 time:14.117
# Prob.1   , res:5.6158e+05,	 time:14.148
# Prob.1   , res:6.5981e+05,	 time:13.916
# Prob.1   , res:1.0995e+06,	 time:14.068
# Prob.1   , res:9.3760e+05,	 time:13.969
# Prob.1   , res:6.2886e+05,	 time:14.096
# Prob.1   , res:7.2766e+05,	 time:14.007
# Prob.1   , res:7.7645e+05,	 time:13.983
# Prob.1   , res:7.8701e+05,	 time:14.137
# Prob.1   , res:1.9228e+06,	 time:14.126
# Prob.1   , res:1.0195e+06,	 time:14.011
# Prob.1   , res:6.9361e+05,	 time:14.281
# Prob.1   , res:3.0421e+05,	 time:14.099
# Prob.1   , res:9.7978e+05,	 time:14.403
# Prob.2   , res:1.4665e+03,	 time:15.999
# Prob.2   , res:1.7738e+03,	 time:16.162
# Prob.2   , res:1.1473e+03,	 time:16.776
# Prob.2   , res:1.9454e+03,	 time:16.584
# Prob.2   , res:1.7955e+03,	 time:16.662
# Prob.2   , res:1.4785e+03,	 time:17.409
# Prob.2   , res:1.5348e+03,	 time:16.715
# Prob.2   , res:1.7086e+03,	 time:16.736
# Prob.2   , res:1.8646e+03,	 time:16.860
# Prob.2   , res:2.2812e+03,	 time:16.493
# Prob.2   , res:1.6804e+03,	 time:17.492
# Prob.2   , res:1.9190e+03,	 time:16.379
# Prob.2   , res:1.9121e+03,	 time:16.284
# Prob.2   , res:1.7455e+03,	 time:17.143
# Prob.2   , res:1.9437e+03,	 time:16.843
# Prob.2   , res:1.4059e+03,	 time:17.059
# Prob.2   , res:1.9224e+03,	 time:16.388
# Prob.2   , res:1.6113e+03,	 time:16.500
# Prob.2   , res:1.7759e+03,	 time:16.252
# Prob.2   , res:1.4892e+03,	 time:16.816
# Prob.2   , res:1.2633e+03,	 time:16.115
# Prob.2   , res:1.5059e+03,	 time:16.597
# Prob.2   , res:1.4150e+03,	 time:16.426
# Prob.2   , res:1.5930e+03,	 time:16.208
# Prob.2   , res:1.7903e+03,	 time:16.566
# Prob.2   , res:1.9531e+03,	 time:16.608
# Prob.2   , res:1.4573e+03,	 time:16.448
# Prob.2   , res:1.9470e+03,	 time:15.857
# Prob.2   , res:1.2833e+03,	 time:15.834
# Prob.2   , res:2.1645e+03,	 time:16.395
# Prob.3   , res:7.2668e+02,	 time:15.261
# Prob.3   , res:7.4102e+02,	 time:15.467
# Prob.3   , res:7.4024e+02,	 time:16.078
# Prob.3   , res:7.2573e+02,	 time:15.347
# Prob.3   , res:7.3762e+02,	 time:15.864
# Prob.3   , res:7.3569e+02,	 time:14.774
# Prob.3   , res:7.4507e+02,	 time:15.116
# Prob.3   , res:7.4028e+02,	 time:15.658
# Prob.3   , res:7.2755e+02,	 time:15.532
# Prob.3   , res:7.3211e+02,	 time:16.399
# Prob.3   , res:7.3982e+02,	 time:16.354
# Prob.3   , res:7.3571e+02,	 time:15.852
# Prob.3   , res:7.2269e+02,	 time:15.448
# Prob.3   , res:7.4625e+02,	 time:16.246
# Prob.3   , res:7.3296e+02,	 time:15.426
# Prob.3   , res:7.4327e+02,	 time:15.541
# Prob.3   , res:7.3672e+02,	 time:15.467
# Prob.3   , res:7.3457e+02,	 time:15.629
# Prob.3   , res:7.3840e+02,	 time:14.803
# Prob.3   , res:7.4588e+02,	 time:14.929
# Prob.3   , res:7.4872e+02,	 time:14.876
# Prob.3   , res:7.4274e+02,	 time:14.283
# Prob.3   , res:7.3317e+02,	 time:14.657
# Prob.3   , res:7.3952e+02,	 time:14.446
# Prob.3   , res:7.4674e+02,	 time:14.596
# Prob.3   , res:7.2680e+02,	 time:14.187
# Prob.3   , res:7.3794e+02,	 time:14.922
# Prob.3   , res:7.4151e+02,	 time:14.374
# Prob.3   , res:7.3466e+02,	 time:15.009
# Prob.3   , res:7.3081e+02,	 time:13.841
# Prob.4   , res:1.9027e+03,	 time:14.632
# Prob.4   , res:1.9036e+03,	 time:14.720
# Prob.4   , res:1.9036e+03,	 time:14.146
# Prob.4   , res:1.9043e+03,	 time:13.414
# Prob.4   , res:1.9044e+03,	 time:13.303
# Prob.4   , res:1.9033e+03,	 time:12.897
# Prob.4   , res:1.9032e+03,	 time:13.323
# Prob.4   , res:1.9048e+03,	 time:12.793
# Prob.4   , res:1.9038e+03,	 time:13.096
# Prob.4   , res:1.9029e+03,	 time:13.309
# Prob.4   , res:1.9031e+03,	 time:12.815
# Prob.4   , res:1.9033e+03,	 time:12.768
# Prob.4   , res:1.9041e+03,	 time:12.744
# Prob.4   , res:1.9037e+03,	 time:12.898
# Prob.4   , res:1.9045e+03,	 time:12.712
# Prob.4   , res:1.9034e+03,	 time:13.089
# Prob.4   , res:1.9049e+03,	 time:12.786
# Prob.4   , res:1.9037e+03,	 time:12.703
# Prob.4   , res:1.9031e+03,	 time:12.922
# Prob.4   , res:1.9046e+03,	 time:13.562
# Prob.4   , res:1.9037e+03,	 time:13.261
# Prob.4   , res:1.9038e+03,	 time:13.521
# Prob.4   , res:1.9023e+03,	 time:13.423
# Prob.4   , res:1.9040e+03,	 time:13.036
# Prob.4   , res:1.9043e+03,	 time:13.497
# Prob.4   , res:1.9047e+03,	 time:12.964
# Prob.4   , res:1.9029e+03,	 time:13.118
# Prob.4   , res:1.9026e+03,	 time:13.246
# Prob.4   , res:1.9041e+03,	 time:13.143
# Prob.4   , res:1.9024e+03,	 time:13.228
# Prob.5   , res:1.1801e+04,	 time:14.197
# Prob.5   , res:1.2314e+04,	 time:13.528
# Prob.5   , res:4.1312e+03,	 time:13.627
# Prob.5   , res:8.3905e+03,	 time:13.891
# Prob.5   , res:3.6170e+04,	 time:13.584
# Prob.5   , res:9.6695e+03,	 time:13.693
# Prob.5   , res:1.4877e+05,	 time:14.130
# Prob.5   , res:7.5416e+03,	 time:14.036
# Prob.5   , res:6.9482e+04,	 time:13.555
# Prob.5   , res:5.2860e+04,	 time:13.685
# Prob.5   , res:4.6491e+04,	 time:14.174
# Prob.5   , res:2.6257e+04,	 time:14.278
# Prob.5   , res:5.7667e+04,	 time:13.615
# Prob.5   , res:4.5784e+03,	 time:14.479
# Prob.5   , res:1.0710e+04,	 time:14.799
# Prob.5   , res:2.2693e+04,	 time:14.545
# Prob.5   , res:5.6575e+03,	 time:14.572
# Prob.5   , res:2.8348e+04,	 time:13.906
# Prob.5   , res:8.2910e+03,	 time:14.290
# Prob.5   , res:1.7995e+04,	 time:15.345
# Prob.5   , res:1.3700e+04,	 time:15.226
# Prob.5   , res:1.6617e+04,	 time:14.939
# Prob.5   , res:6.4834e+03,	 time:14.964
# Prob.5   , res:2.6900e+04,	 time:14.943
# Prob.5   , res:3.6223e+04,	 time:14.930
# Prob.5   , res:7.2233e+03,	 time:15.302
# Prob.5   , res:2.1472e+04,	 time:15.217
# Prob.5   , res:6.7530e+03,	 time:15.158
# Prob.5   , res:3.2343e+04,	 time:14.936
# Prob.5   , res:1.4206e+04,	 time:15.258
# Prob.6   , res:1.6414e+03,	 time:14.741
# Prob.6   , res:1.7958e+03,	 time:14.744
# Prob.6   , res:1.6199e+03,	 time:15.316
# Prob.6   , res:1.6271e+03,	 time:14.731
# Prob.6   , res:1.6177e+03,	 time:14.423
# Prob.6   , res:1.6432e+03,	 time:14.648
# Prob.6   , res:1.6208e+03,	 time:14.579
# Prob.6   , res:1.6227e+03,	 time:15.188
# Prob.6   , res:1.6924e+03,	 time:15.399
# Prob.6   , res:1.6523e+03,	 time:14.676
# Prob.6   , res:1.6188e+03,	 time:14.580
# Prob.6   , res:1.6634e+03,	 time:14.030
# Prob.6   , res:1.7321e+03,	 time:14.175
# Prob.6   , res:1.6370e+03,	 time:14.388
# Prob.6   , res:1.6633e+03,	 time:14.247
# Prob.6   , res:1.7102e+03,	 time:13.937
# Prob.6   , res:1.6424e+03,	 time:13.984
# Prob.6   , res:1.8139e+03,	 time:14.078
# Prob.6   , res:1.7300e+03,	 time:15.059
# Prob.6   , res:1.7800e+03,	 time:14.610
# Prob.6   , res:1.6301e+03,	 time:14.282
# Prob.6   , res:1.7808e+03,	 time:14.275
# Prob.6   , res:1.6255e+03,	 time:14.880
# Prob.6   , res:1.6513e+03,	 time:14.154
# Prob.6   , res:1.7935e+03,	 time:14.303
# Prob.6   , res:1.8217e+03,	 time:13.913
# Prob.6   , res:1.6515e+03,	 time:13.813
# Prob.6   , res:1.8074e+03,	 time:15.345
# Prob.6   , res:1.6341e+03,	 time:15.237
# Prob.6   , res:1.6897e+03,	 time:14.819
# Prob.7   , res:3.9739e+03,	 time:14.382
# Prob.7   , res:3.3790e+03,	 time:14.797
# Prob.7   , res:4.4397e+03,	 time:13.845
# Prob.7   , res:6.1906e+03,	 time:14.230
# Prob.7   , res:5.8531e+03,	 time:14.466
# Prob.7   , res:3.8704e+03,	 time:14.693
# Prob.7   , res:3.8590e+03,	 time:14.485
# Prob.7   , res:3.3068e+03,	 time:13.878
# Prob.7   , res:5.3781e+03,	 time:13.828
# Prob.7   , res:3.8154e+03,	 time:13.781
# Prob.7   , res:3.4489e+03,	 time:14.731
# Prob.7   , res:3.8093e+03,	 time:14.610
# Prob.7   , res:6.6413e+03,	 time:14.057
# Prob.7   , res:4.6201e+03,	 time:13.992
# Prob.7   , res:5.6081e+03,	 time:14.106
# Prob.7   , res:3.9483e+03,	 time:14.330
# Prob.7   , res:4.1732e+03,	 time:14.071
# Prob.7   , res:5.4124e+03,	 time:13.926
# Prob.7   , res:3.1847e+03,	 time:13.937
# Prob.7   , res:4.9375e+03,	 time:14.447
# Prob.7   , res:3.1478e+03,	 time:14.922
# Prob.7   , res:6.9515e+03,	 time:14.979
# Prob.7   , res:4.2589e+03,	 time:14.006
# Prob.7   , res:3.8137e+03,	 time:13.939
# Prob.7   , res:5.0810e+03,	 time:14.250
# Prob.7   , res:2.8802e+03,	 time:14.273
# Prob.7   , res:3.3908e+03,	 time:13.923
# Prob.7   , res:4.6351e+03,	 time:13.909
# Prob.7   , res:5.7911e+03,	 time:13.910
# Prob.7   , res:3.6342e+03,	 time:13.964
# Prob.8   , res:2.3079e+03,	 time:17.780
# Prob.8   , res:2.3092e+03,	 time:18.633
# Prob.8   , res:2.3102e+03,	 time:17.630
# Prob.8   , res:2.3095e+03,	 time:17.641
# Prob.8   , res:2.2386e+03,	 time:18.565
# Prob.8   , res:2.3091e+03,	 time:17.761
# Prob.8   , res:2.3085e+03,	 time:17.681
# Prob.8   , res:2.2327e+03,	 time:17.590
# Prob.8   , res:2.3082e+03,	 time:18.538
# Prob.8   , res:2.3082e+03,	 time:17.672
# Prob.8   , res:2.3096e+03,	 time:18.516
# Prob.8   , res:2.2315e+03,	 time:17.577
# Prob.8   , res:2.3098e+03,	 time:17.647
# Prob.8   , res:2.2269e+03,	 time:17.861
# Prob.8   , res:2.3096e+03,	 time:17.684
# Prob.8   , res:2.2362e+03,	 time:18.204
# Prob.8   , res:2.2454e+03,	 time:18.379
# Prob.8   , res:2.3063e+03,	 time:18.098
# Prob.8   , res:2.2324e+03,	 time:18.366
# Prob.8   , res:2.3078e+03,	 time:18.087
# Prob.8   , res:2.2614e+03,	 time:17.767
# Prob.8   , res:2.2365e+03,	 time:17.608
# Prob.8   , res:2.3095e+03,	 time:18.128
# Prob.8   , res:2.3103e+03,	 time:17.666
# Prob.8   , res:2.2252e+03,	 time:17.665
# Prob.8   , res:2.2288e+03,	 time:17.615
# Prob.8   , res:2.3099e+03,	 time:17.776
# Prob.8   , res:2.2021e+03,	 time:17.741
# Prob.8   , res:2.2406e+03,	 time:17.895
# Prob.8   , res:2.2165e+03,	 time:17.556
# Prob.9   , res:2.5019e+03,	 time:18.112
# Prob.9   , res:2.5023e+03,	 time:18.267
# Prob.9   , res:2.5028e+03,	 time:18.042
# Prob.9   , res:2.7431e+03,	 time:18.056
# Prob.9   , res:2.4368e+03,	 time:18.232
# Prob.9   , res:2.5033e+03,	 time:18.037
# Prob.9   , res:2.5025e+03,	 time:18.029
# Prob.9   , res:2.7540e+03,	 time:18.055
# Prob.9   , res:2.7497e+03,	 time:17.991
# Prob.9   , res:2.5028e+03,	 time:18.342
# Prob.9   , res:2.7400e+03,	 time:18.148
# Prob.9   , res:2.7359e+03,	 time:18.592
# Prob.9   , res:2.5025e+03,	 time:18.050
# Prob.9   , res:2.7408e+03,	 time:18.079
# Prob.9   , res:2.5023e+03,	 time:18.099
# Prob.9   , res:2.5027e+03,	 time:18.029
# Prob.9   , res:2.5023e+03,	 time:18.086
# Prob.9   , res:2.7433e+03,	 time:18.003
# Prob.9   , res:2.7436e+03,	 time:18.064
# Prob.9   , res:2.7484e+03,	 time:18.027
# Prob.9   , res:2.7451e+03,	 time:17.914
# Prob.9   , res:2.7402e+03,	 time:18.166
# Prob.9   , res:2.7434e+03,	 time:18.061
# Prob.9   , res:2.7426e+03,	 time:17.958
# Prob.9   , res:2.7418e+03,	 time:17.943
# Prob.9   , res:2.5016e+03,	 time:18.044
# Prob.9   , res:2.7386e+03,	 time:17.913
# Prob.9   , res:2.7536e+03,	 time:17.972
# Prob.9   , res:2.6103e+03,	 time:17.990
# Prob.9   , res:2.7405e+03,	 time:18.004
# Prob.10  , res:2.8994e+03,	 time:18.237
# Prob.10  , res:2.8993e+03,	 time:17.954
# Prob.10  , res:2.8985e+03,	 time:17.916
# Prob.10  , res:2.8980e+03,	 time:17.954
# Prob.10  , res:2.8992e+03,	 time:17.944
# Prob.10  , res:2.8984e+03,	 time:18.014
# Prob.10  , res:2.8996e+03,	 time:18.729
# Prob.10  , res:2.8993e+03,	 time:17.991
# Prob.10  , res:2.8993e+03,	 time:18.043
# Prob.10  , res:2.9000e+03,	 time:18.021
# Prob.10  , res:2.8994e+03,	 time:18.033
# Prob.10  , res:2.8981e+03,	 time:17.989
# Prob.10  , res:2.9484e+03,	 time:17.982
# Prob.10  , res:2.9448e+03,	 time:18.068
# Prob.10  , res:2.9445e+03,	 time:18.131
# Prob.10  , res:2.8991e+03,	 time:18.122
# Prob.10  , res:2.8982e+03,	 time:18.068
# Prob.10  , res:2.8994e+03,	 time:18.232
# Prob.10  , res:2.8995e+03,	 time:18.954
# Prob.10  , res:2.8982e+03,	 time:18.466
# Prob.10  , res:2.8990e+03,	 time:18.090
# Prob.10  , res:2.8994e+03,	 time:18.031
# Prob.10  , res:2.8983e+03,	 time:18.031
# Prob.10  , res:2.9458e+03,	 time:17.982
# Prob.10  , res:2.8992e+03,	 time:18.016
# Prob.10  , res:2.9006e+03,	 time:17.997
# Prob.10  , res:2.9011e+03,	 time:18.043
# Prob.10  , res:2.8992e+03,	 time:18.523
# Prob.10  , res:2.9454e+03,	 time:18.650
# Prob.10  , res:2.8994e+03,	 time:18.140
# [[1821121.604314853, 530302.9705547999, 590672.6707823771, 1246658.635386521, 900921.2535080427, 1375622.0065882306, 660148.6234417423, 1240174.4011337233, 473473.42923204065, 580922.6625188752, 919354.3666192044, 649062.5052678894, 913369.4262818098, 818142.7109636415, 931510.2152414477, 506189.65988079464, 469122.7181643804, 561577.097055696, 659810.7819369952, 1099504.0475319081, 937595.8830412703, 628858.1177721734, 727663.2292713437, 776446.2947400558, 787007.1095860987, 1922768.6655694423, 1019524.049938532, 693606.894528945, 304214.3591066685, 979781.4066609223], [1466.4666235819523, 1773.7659992550743, 1147.3499967608905, 1945.3903624511272, 1795.5312170572656, 1478.4897402061606, 1534.7831801488073, 1708.5674955545383, 1864.626461749171, 2281.15928431861, 1680.3532110978026, 1918.9924445649676, 1912.0932988431387, 1745.5228206487586, 1943.6702474660783, 1405.9149770241875, 1922.3805205525268, 1611.2753165326344, 1775.9392851571329, 1489.218118453451, 1263.3317063288941, 1505.8868760269415, 1415.0444479137159, 1593.0432859573402, 1790.286714666996, 1953.0993230262661, 1457.291129972367, 1946.9760607022845, 1283.3130439263523, 2164.4553542220674], [726.6770015494325, 741.0232288645713, 740.2378758793373, 725.7256967377583, 737.6183555518285, 735.6874930307263, 745.0709270335974, 740.2750487275533, 727.55067921511, 732.1124946251396, 739.8151549431913, 735.7064213561105, 722.6859617086991, 746.2479242068607, 732.9630091584337, 743.2704615451755, 736.7236052042949, 734.5678687599602, 738.3956831178552, 745.8751502445965, 748.7174149129418, 742.7409773232309, 733.166574132042, 739.5159222741107, 746.7445028619637, 726.7973650940756, 737.9392313699424, 741.5053778960734, 734.6565911588548, 730.8140319100653], [1902.7449739002261, 1903.590323097819, 1903.6366858106535, 1904.3294290683007, 1904.3658177198683, 1903.2874084612786, 1903.2025484340415, 1904.8300422718546, 1903.7653994771442, 1902.9433860514355, 1903.079160441899, 1903.2560369758294, 1904.0502929178756, 1903.6996123095935, 1904.468751964961, 1903.390749234041, 1904.9489468964555, 1903.7112478337374, 1903.1226521591286, 1904.5846006273227, 1903.7238107700875, 1903.798227286265, 1902.2784008172002, 1904.0452411247127, 1904.340072875402, 1904.7471210057265, 1902.8936360862454, 1902.6016937678673, 1904.0788213774686, 1902.4023650617737], [11800.776454891151, 12314.276966991049, 4131.244229984946, 8390.506247666432, 36170.06299577868, 9669.515151152322, 148774.57463593263, 7541.587345183792, 69482.31672492849, 52860.15497219615, 46490.72467679226, 26256.567359090932, 57666.58743716226, 4578.367292558062, 10709.630339252064, 22692.74068474761, 5657.470614204335, 28348.284546752697, 8290.988615997809, 17995.344917323604, 13700.004092076411, 16616.884307603417, 6483.357228830806, 26899.89361059628, 36223.44040046427, 7223.330478188237, 21472.240608451342, 6753.0414604640055, 32343.07143466535, 14206.417740910607], [1641.3703841243089, 1795.7659795158274, 1619.8711376283013, 1627.059088283371, 1617.665619062907, 1643.2127408499855, 1620.8398103653435, 1622.6940016793128, 1692.4013771350171, 1652.313596969821, 1618.8241893298307, 1663.360696008558, 1732.0601189899555, 1637.021833679032, 1663.3488139631993, 1710.2270687499936, 1642.4171499340343, 1813.939279284356, 1730.037766417226, 1780.0415281905919, 1630.057944444952, 1780.7889980534317, 1625.5284487601052, 1651.295022172653, 1793.5447621948888, 1821.7066399386226, 1651.4617863628475, 1807.4276145326057, 1634.1012177795906, 1689.7178737250822], [3973.9340233660937, 3379.0253070093177, 4439.656444623906, 6190.636428264305, 5853.135361527749, 3870.4427069067215, 3858.992260931075, 3306.8248537821137, 5378.145984225455, 3815.380975559688, 3448.852641321415, 3809.282888745761, 6641.2588036837205, 4620.091252064644, 5608.121260709167, 3948.3304019330185, 4173.179987005089, 5412.38134015276, 3184.70789669887, 4937.475905024639, 3147.78180152012, 6951.502723545606, 4258.94321519856, 3813.7096980842607, 5081.047518983734, 2880.1 ...

# %% [markdown]
# ## Results Comparing
#
# We provide useful comparing script for our formatted result records in `mpopt.tools.result.py`. (The printed results is formatted in terminal.)
#
# Providing two result paths, the script will conduct a statistical comparation:

# %%
# !python ../mpopt/tools/result.py ../logs/CEC20_10D/AGSK.json ../logs/CEC20_10D/LoTFWA.json --b CEC20 -d 10
# Out:
# Comparing on CEC20: alg1: AGSK, alg2: LoTFWA__test
# Win: 0, Lose: 10
# +-----+-----------+-----------+-----------+-----------+---------+-----+
# | idx | alg1.mean |  alg1.std | alg2.mean |  alg2.std | P-value | Sig |
# +-----+-----------+-----------+-----------+-----------+---------+-----+
# |  1  | 0.000e+00 | 0.000e+00 | 8.574e+05 | 3.675e+05 |   0.00  |  +  |
# |  2  | 2.845e+01 | 3.152e+01 | 5.925e+02 | 2.662e+02 |   0.00  |  +  |
# |  3  | 9.925e+00 | 4.186e+00 | 3.703e+01 | 6.706e+00 |   0.00  |  +  |
# |  4  | 5.826e-02 | 3.061e-02 | 3.664e+00 | 7.167e-01 |   0.00  |  +  |
# |  5  | 3.176e-01 | 3.008e-01 | 2.402e+04 | 2.837e+04 |   0.00  |  +  |
# |  6  | 1.547e-01 | 1.154e-01 | 8.700e+01 | 6.906e+01 |   0.00  |  +  |
# |  7  | 1.537e-03 | 1.682e-03 | 2.348e+03 | 1.083e+03 |   0.00  |  +  |
# |  8  | 1.800e+01 | 2.339e+01 | 7.327e+01 | 3.921e+01 |   0.00  |  +  |
# |  9  | 7.629e+01 | 4.214e+01 | 2.406e+02 | 1.203e+02 |   0.00  |  +  |
# |  10 | 2.985e+02 | 1.404e+02 | 4.069e+02 | 1.740e+01 |   0.00  |  +  |
# +-----+-----------+-----------+-----------+-----------+---------+-----+

# %% [markdown]
# Providing more than two paths or a directory path, the script will conduct a averange ranking comparation:

# %%
# !python ../mpopt/tools/result.py ../logs/CEC20_10D/ --b CEC20 -d 10
# Out:
# Comparing on CEC20:
# +---------+-----------+-----------+-------------------+------------------+------------+-----------+
# |   idx   | AGSK.mean |  AGSK.std | LoTFWA__test.mean | LoTFWA__test.std | IMODE.mean | IMODE.std |
# +---------+-----------+-----------+-------------------+------------------+------------+-----------+
# |    1    | 1.000e+02 | 0.000e+00 |     8.575e+05     |    3.675e+05     | 1.000e+02  | 0.000e+00 |
# |    2    | 1.128e+03 | 3.152e+01 |     1.692e+03     |    2.662e+02     | 1.104e+03  | 3.639e+00 |
# |    3    | 7.099e+02 | 4.186e+00 |     7.370e+02     |    6.706e+00     | 7.121e+02  | 7.694e-01 |
# |    4    | 1.900e+03 | 3.061e-02 |     1.904e+03     |    7.167e-01     | 1.900e+03  | 0.000e+00 |
# |    5    | 1.700e+03 | 3.008e-01 |     2.572e+04     |    2.837e+04     | 1.700e+03  | 3.768e-01 |
# |    6    | 1.600e+03 | 1.154e-01 |     1.687e+03     |    6.906e+01     | 1.600e+03  | 4.996e-02 |
# |    7    | 2.100e+03 | 1.682e-03 |     4.448e+03     |    1.083e+03     | 2.100e+03  | 1.078e-03 |
# |    8    | 2.218e+03 | 2.339e+01 |     2.273e+03     |    3.921e+01     | 2.203e+03  | 7.333e+00 |
# |    9    | 2.476e+03 | 4.214e+01 |     2.641e+03     |    1.203e+02     | 2.441e+03  | 4.388e+01 |
# |    10   | 2.798e+03 | 1.404e+02 |     2.907e+03     |    1.740e+01     | 2.898e+03  | 4.547e-13 |
# | AvgRank |    1.60   |           |        2.90       |                  |    1.30    |           |
# +---------+-----------+-----------+-------------------+------------------+------------+-----------+
